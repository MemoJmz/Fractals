# %%
# Mandelbrot Set
# {c} such that z -> z*z  + c
# remains finite stanting with z = 0

# c = 0 -> 0, 0, ...
# c = 1 -> 0, 1, 2, 5, 26, ... -> explotes
# c = -1 -> Does not explote
# c = -2 -> Remains finite

# %%
c = -1
z = 0

# %%
z = z * z + c
z
# Out:
# -1

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\gajim\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['re']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
x = numpy.arange(-3 , 3, 1)
z = numpy.zeros_like(x)
arr = [x]
for i in range(10):
    z = z*z + x
    arr.append(numpy.abs(z))

# %%
arr
# Out:
# [array([-3, -2, -1,  0,  1,  2]),
#  array([3, 2, 1, 0, 1, 2]),
#  array([6, 2, 0, 0, 2, 6]),
#  array([33,  2,  1,  0,  5, 38]),
#  array([1086,    2,    0,    0,   26, 1446]),
#  array([1179393,       2,       1,       0,     677, 2090918]),
#  array([601555458,         2,         0,         0,    458330, 338624602]),
#  array([ 76543999,         2,         1,         0, 387008603, 822878118]),
#  array([ 148893698,          2,          0,          0,  176771162,
#         2022072410]),
#  array([ 612352001,          2,          1,          0,  562847653,
#         1652268966]),
#  array([1493139454,          2,          0,          0, 1244913754,
#          451698778])]

# %%
z
# Out:
# array([1493139454,          2,          0,          0, 1244913754,
#        -451698778])

# %%
x = numpy.arange(-3 , 3, 0.01)
z = numpy.zeros_like(x)
arr = [x]
for i in range(10):
    z = z*z + x
    arr.append(numpy.abs(z)<100)

# %%
arr
# Out:
# [array([-3.00000000e+00, -2.99000000e+00, -2.98000000e+00, -2.97000000e+00,
#         -2.96000000e+00, -2.95000000e+00, -2.94000000e+00, -2.93000000e+00,
#         -2.92000000e+00, -2.91000000e+00, -2.90000000e+00, -2.89000000e+00,
#         -2.88000000e+00, -2.87000000e+00, -2.86000000e+00, -2.85000000e+00,
#         -2.84000000e+00, -2.83000000e+00, -2.82000000e+00, -2.81000000e+00,
#         -2.80000000e+00, -2.79000000e+00, -2.78000000e+00, -2.77000000e+00,
#         -2.76000000e+00, -2.75000000e+00, -2.74000000e+00, -2.73000000e+00,
#         -2.72000000e+00, -2.71000000e+00, -2.70000000e+00, -2.69000000e+00,
#         -2.68000000e+00, -2.67000000e+00, -2.66000000e+00, -2.65000000e+00,
#         -2.64000000e+00, -2.63000000e+00, -2.62000000e+00, -2.61000000e+00,
#         -2.60000000e+00, -2.59000000e+00, -2.58000000e+00, -2.57000000e+00,
#         -2.56000000e+00, -2.55000000e+00, -2.54000000e+00, -2.53000000e+00,
# ...

# %%
figure(figsize=(10,10))
imshow(arr, extent=(x.min(), x.max(), -3, 3))
colorbar()

# %%
min(x[arr[-1]])
# Out:
# -2.0000000000000213

# %%
max(x[arr[-1]])
# Out:
# 0.3599999999999284

# %%
x, X = -2, 2
y, Y = -1, 1

delta = 0.001

re, im = numpy.mgrid[x:X:delta, y:Y:delta]

# %%
re
# Out:
# array([[-2.   , -2.   , -2.   , ..., -2.   , -2.   , -2.   ],
#        [-1.999, -1.999, -1.999, ..., -1.999, -1.999, -1.999],
#        [-1.998, -1.998, -1.998, ..., -1.998, -1.998, -1.998],
#        ...,
#        [ 1.997,  1.997,  1.997, ...,  1.997,  1.997,  1.997],
#        [ 1.998,  1.998,  1.998, ...,  1.998,  1.998,  1.998],
#        [ 1.999,  1.999,  1.999, ...,  1.999,  1.999,  1.999]])

# %%
im
# Out:
# array([[-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999],
#        [-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999],
#        [-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999],
#        ...,
#        [-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999],
#        [-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999],
#        [-1.   , -0.999, -0.998, ...,  0.997,  0.998,  0.999]])

# %%
# %pylab inline

x, X = -2, 1
y, Y = -1, 1

delta = 0.001

re, im = numpy.mgrid[x:X:delta, y:Y:delta]
c = (re + 1j*im).reshape(im.shape[0], -1).T

z = numpy.zeros_like(c)
for i in range(100):
    z = z*z + c  # Mandelbrot eq

figure(figsize=(20,10))
imshow(numpy.absolute(z), extent=(x, X, y, Y))
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/176541352.py:11: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/176541352.py:11: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq

# %%
# %pylab inline

x, X = -2, 1
y, Y = -1, 1

delta = 0.001

re, im = numpy.mgrid[x:X:delta, y:Y:delta]
c = (re + 1j*im).reshape(im.shape[0], -1).T

z = numpy.zeros_like(c)
escape = numpy.zeros_like(numpy.absolute(c))
for i in range(100):
    z = z*z + c  # Mandelbrot eq
    idx = (numpy.absolute(z)>4) & (escape == 0)
    escape[idx] = i

figure(figsize=(20,10))
imshow(escape, extent=(x, X, y, Y))
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/3807101528.py:12: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/3807101528.py:12: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/3807101528.py:13: RuntimeWarning: overflow encountered in absolute
#   idx = (numpy.absolute(z)>4) & (escape == 0)

# %%
# %pylab inline

def plot_mandelbrot(x, X, y, Y):
    delta = (X-x)/1000
    re, im = numpy.mgrid[x:X:delta, y:Y:delta]
    c = (re + 1j*im).reshape(im.shape[0], -1).T

    z = numpy.zeros_like(c)
    escape = numpy.zeros_like(numpy.absolute(c))
    for i in range(150):
        z = z*z + c  # Mandelbrot eq
        idx = (numpy.absolute(z)>4) & (escape == 0)
        escape[idx] = i

    figure(figsize=(20,10))
    imshow(escape, extent=(x, X, y, Y), cmap="plasma")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot_mandelbrot(-2.25, 1, -1.25, 1.25)
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/1420410396.py:11: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/1420410396.py:11: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/1420410396.py:12: RuntimeWarning: overflow encountered in absolute
#   idx = (numpy.absolute(z)>4) & (escape == 0)

# %%
def plot_mandelbrot_at(x, y, D):
    return plot_mandelbrot(x-D, x+D, y-D, y+D)

# %%
plot_mandelbrot_at(-.5, -.75, .3)
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:11: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:11: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:12: RuntimeWarning: overflow encountered in absolute
#   idx = (numpy.absolute(z)>4) & (escape == 0)

# %%
plot_mandelbrot_at(-.75, -.25, .1)
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:11: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:11: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/2481178257.py:12: RuntimeWarning: overflow encountered in absolute
#   idx = (numpy.absolute(z)>4) & (escape == 0)

# %%
# %pylab inline

def plot_mandelbrot(x, X, y, Y):
    delta = (X-x)/800
    re, im = numpy.mgrid[x:X:delta, y:Y:delta]
    c = (re + 1j*im).reshape(im.shape[0], -1).T

    z = numpy.zeros_like(c)
    escape = numpy.zeros_like(numpy.absolute(c))
    for i in range(1000):
        z = z*z + c  # Mandelbrot eq
        idx = (numpy.absolute(z)>4) & (escape == 0)
        escape[idx] = i

    figure(figsize=(20,10))
    imshow(escape, extent=(x, X, y, Y), cmap="plasma")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot_mandelbrot_at(-.74, -.17, .02)
# Out:
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/478323014.py:11: RuntimeWarning: overflow encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/478323014.py:11: RuntimeWarning: invalid value encountered in multiply
#   z = z*z + c  # Mandelbrot eq
# C:\Users\gajim\AppData\Local\Temp/ipykernel_2616/478323014.py:12: RuntimeWarning: overflow encountered in absolute
#   idx = (numpy.absolute(z)>4) & (escape == 0)
